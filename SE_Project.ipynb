# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Import Data and Drop Columns

# %%
nutrient_data = pd.read_excel('/home/anna/Desktop/Stream Ecology/Ecel Sheets/Antarctic_Season1_CNP_Enzymes_Metadata_no_formulas.xlsx')
nutrient_data.columns
# nutrient_data.head()
nutrient_data = nutrient_data.drop(columns=['Wet_dry_conversion', 'Qubit_raw_ng/uL','g_wet_extracted_DNA', 'Qubit_ng_DNA/g_cryo',
       'Chl-a_raw_ug/L', 'g_wet_extracted_chla', 'ug_chl-a/g_cryo',
       'g_weighboat', 'g_wet', 'g_dry_plusboat', 'g_ashed_plusboat', 'Tardigrades_extracted', 'Rotifers_extracted',
       'Ciliates_extracted', 'ml_in_extraction', 'ml_counted', 
      'TC_percent', 'TN_percent', 'BG/(NAG+LAP)', '(NAG+LAP)/Phos',
       'BG/Phos', 'AG', 'BG', 'BXYL', 'CBH', 'LAP', 'NAG', 'PHOS',
       'percent_OM_nonacifidified', 'percent_OM_acid',
       'percent_OM_leached_with_water_instead_of_acid'])
nutrient_data.head()
# Out:
#   SampleID  Fluorescence  percent_organic  g_wet_microfauna  \
# 0   CAA001         11.90             0.63            19.535
# 1   CAA002          2.20             0.93            19.763
# 2   CAA003          7.29              NaN            20.004
# 3   CAA004           NaN              NaN             0.000
# 4   CAA005          5.54             0.62            14.263
#
#    Tardigrades/g_dry  Rotifers/g_dry  Ciliates/g_dry  Diameter_1_cm  \
# 0               0.22            0.25            0.00           28.0
# 1               0.37            0.09            0.00           27.0
# 2               0.48            0.73            0.25           25.0
# 3                NaN             NaN             NaN           23.0
# 4               0.19            0.06            0.00           17.5
#
#    Diameter_2_cm  Depth_cm  pH_lab  electrical_conductivity  TC_ppm  TN_ppm  \
# 0             28        22    6.69                     85.9  2407.0   305.0
# 1             27        25     NaN                      NaN  2602.0   412.0
# 2             27        19     NaN                      NaN  2252.0   361.0
# 3             25        23     NaN                      NaN  3227.0   499.0
# 4             19        23    7.87                     64.5  2100.0   333.0
#
#    TP_ppm
# 0    19.0
# 1   270.0
# 2   114.0
# 3   261.0
# 4   163.0

# %% [markdown]
# ### Canada Glacier Filling in Missing Values using the Mean of Each Column

# %%
caa = nutrient_data.iloc[:30]
caa_columns = caa.columns
print(caa_columns[0])


per_org_mean = caa['percent_organic'].mean()
f_mean = caa['Fluorescence'].mean()
microfauna_mean = caa['g_wet_microfauna'].mean()
tard_mean = caa['Tardigrades/g_dry'].mean()
rot_mean = caa['Rotifers/g_dry'].mean()
cil_mean = caa['Ciliates/g_dry'].mean()
ph_mean = caa['pH_lab'].mean()
elec_mean = caa['electrical_conductivity'].mean()

caa['percent_organic'].fillna(per_org_mean, inplace=True)
caa['Fluorescence'].fillna(f_mean, inplace=True)
caa['g_wet_microfauna'].fillna(microfauna_mean, inplace=True)
caa['Tardigrades/g_dry'].fillna(tard_mean, inplace=True)
caa['Rotifers/g_dry'].fillna(rot_mean, inplace=True)
caa['Ciliates/g_dry'].fillna(cil_mean, inplace=True)
caa['pH_lab'].fillna(ph_mean, inplace=True)
caa['electrical_conductivity'].fillna(elec_mean, inplace=True)
# Out:
# SampleID
# /tmp/ipykernel_577360/3862988870.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['percent_organic'].fillna(per_org_mean, inplace=True)
# /tmp/ipykernel_577360/3862988870.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['Fluorescence'].fillna(f_mean, inplace=True)
# /tmp/ipykernel_577360/3862988870.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['g_wet_microfauna'].fillna(microfauna_mean, inplace=True)
# /tmp/ipykernel_577360/3862988870.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['Tardigrades/g_dry'].fillna(tard_mean, inplace=True)
# /tmp/ipykernel_577360/3862988870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['Rotifers/g_dry'].fillna(rot_mean, inplace=True)
# /tmp/ipykernel_577360/3862988870.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['Ciliates/g_dry'].fillna(cil_mean, inplace=True)
# /tmp/ipykernel_577360/3862988870.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['pH_lab'].fillna(ph_mean, inplace=True)
# /tmp/ipykernel_577360/3862988870.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caa['electrical_conductivity'].fillna(elec_mean, inplace=True)

# %% [markdown]
# ### Commonwealth Glacier Filling in Missing Values using the Mean of Each Column

# %%
coo = nutrient_data.iloc[30:60]
# print(coo['SampleID'])


per_org_mean = coo['percent_organic'].mean()
f_mean = coo['Fluorescence'].mean()
microfauna_mean = coo['g_wet_microfauna'].mean()
tard_mean = coo['Tardigrades/g_dry'].mean()
rot_mean = coo['Rotifers/g_dry'].mean()
cil_mean = coo['Ciliates/g_dry'].mean()
ph_mean = coo['pH_lab'].mean()
elec_mean = coo['electrical_conductivity'].mean()

coo['percent_organic'].fillna(per_org_mean, inplace=True)
coo['Fluorescence'].fillna(f_mean, inplace=True)
coo['g_wet_microfauna'].fillna(microfauna_mean, inplace=True)
coo['Tardigrades/g_dry'].fillna(tard_mean, inplace=True)
coo['Rotifers/g_dry'].fillna(rot_mean, inplace=True)
coo['Ciliates/g_dry'].fillna(cil_mean, inplace=True)
coo['pH_lab'].fillna(ph_mean, inplace=True)
coo['electrical_conductivity'].fillna(elec_mean, inplace=True)
print(coo)
# Out:
#    SampleID  Fluorescence  percent_organic  g_wet_microfauna  \
# 30   COH001     11.153846         1.410000            20.303
# 31   COH002      4.060000         2.300000            19.416
# 32   COH003     14.200000         1.601905            19.995
# 33   COH004     10.200000         1.600000            19.273
# 34   COH005      9.680000         1.601905            19.143
# 35   COH006     16.700000         2.570000            19.639
# 36   COH007     11.153846         1.601905            20.207
# 37   COH008      4.340000         1.601905            20.173
# 38   COH009      6.910000         1.380000            17.371
# 39   COH010     12.400000         1.310000            19.542
# 40   COH011     15.100000         1.220000            18.864
# 41   COH012      6.620000         1.601905            20.816
# 42   COH013     30.400000         1.960000            19.527
# 43   COH014     11.153846         1.700000            21.376
# 44   COH015     11.700000         1.160000            13.111
# 45   COH016     11.800000         1.601905            17.706
# 46   COH017     19.100000         1.601905            20.942
# 47   COH018      5.500000         2.200000            20.147
# 48   COH019     10.700000         1.200000            14.380
# 49   COH020     26.000000         1.290000            16.968
# 50   COH021     12.600000         1.210000            19.899
# 51   COH022      9.900000         0.910000            21.553
# 52   COH023      6.090000         1.550000            16.619
# 53   COH024      5.310000         1.590000            19.704
# 54   COH025     11.100000         1.700000            19.016
# 55   COH026      8.070000         2.670000            19.031
# 56   COH027     11.153846         1.210000            19.376
# 57   COH028      8.520000         1.500000            19.838
# 58   COH029      4.440000         1.601905            18.084
# 59   COH030      8.560000         1.601905            20.174
#
#     Tardigrades/g_dry  Rotifers/g_dry  Ciliates/g_dry  Diameter_1_cm  \
# 30               0.06            0.21            0.00           18.0
# 31               0.86            0.20            0.07           28.0
# 32               1.09            0.62            0.06           33.0
# 33               0.06            0.31            0.05           24.0
# 34               0.14            0.10            0.00           26.0
# 35               0.00            0.10            0.00           28.0
# 36               0.83            1.04            0.02           18.0
# 37               0.22            0.15            0.00           29.0
# 38               1.00            0.50            0.01           27.0
# 39               0.12            0.43            0.06           30.0
# 40               1.46            1.12            0.03           25.0
# 41               0.35            0.66            1.99           19.0
# 42               0.71            1.19            0.00           23.0
# 43               0.20            0.53            0.00           18.0
# 44               0.23            0.49            0.13           28.0
# 45               0.29            0.25            0.00           26.0
# 46               0.22            1.50            0.12           20.0
# 47               0.47            0.05            0.00           21.0
# 48               0.11            0.30            0.04           23.0
# 49               0.27            0.67            0.04           19.0
# 50               0.56            0.84            0.00           22.0
# 51               0.31            0.77            0.00           25.0
# 52               0.19            0.27            0.00           20.0
# 53               1.58            0.52            0.02           23.0
# 54               0.45            0.23            0.02           24.0
# 55               0.20            0.14            0.00           19.0
# 56               0.51            0.85            0.03           28.0
# 57               1.65            0.97            0.10           25.0
# 58               0.08            0.03            0.00           30.0
# 59               0.89            0.32            0.00           24.0
#
#     Diameter_2_cm  Depth_cm    pH_lab  electrical_conductivity   TC_ppm  \
# 30             18        13  7.225714                    104.1   5679.0
# 31             28        17  7.225714                    104.1  13760.0
# 32             29        18  7.225714                    104.1   3536.0
# 33             21        15  7.225714                    104.1   7428.0
# 34             26        20  7.200000                     96.1  29850.0
# 35             15        16  7.225714                    104.1   7423.0
# 36             22        16  7.225714                    104.1   3054.0
# 37             24        24  7.150000                    106.7   4789.0
# 38             30        17  7.225714                    104.1   3020.0
# 39             30        14  7.225714                    104.1   2313.0
# 40             26        23  7.225714                    104.1   2943.0
# 41             19        20  7.330000                    204.4   9354.0
# 42             18        17  7.225714                    104.1   5977.0
# 43             18        15  7.225714                    104.1   5278.0
# 44             29        14  7.225714                    104.1   3116.0
# 45             25        17  7.250000                     69.1   7492.0
# 46             19        17  7.225714                    104.1   6250.0
# 47             19        15  7.225714                    104.1   4874.0
# 48             21        21  7.225714                    104.1   3109.0
# 49             21        21  7.225714                    104.1   6067.0
# 50             24        12  7.225714                    104.1   2613.0
# 51             22        17  7.225714                    104.1   2972.0
# 52             20        21  7.225714                    104.1   3443.0
# 53             25        19  7.225714                    104.1   9544.0
# 54             25        24  7.225714                    104.1   3480.0
# 55             24        24  6.960000                     89.2   2968.0
# 56             22        24  7.225714                    104.1   4578.0
# 57             25        20  7.225714                    104.1   3613.0
# 58             24        17  7.280000                     81.5  12750.0
# 59             27        18  7.410000                     81.7   1636.0
#
#     TN_ppm  TP_ppm
# 30  1108.0   154.0
# 31  2093.0   255.0
# 32   722.0    66.3
# 33  1258.0   200.0
# 34  3846.0   136.0
# 35  1298.0   133.0
# 36   644.0   147.0
# 37   909.0   135.0
# 38   506.0   129.0
# 39   486.0   181.0
# 40   505.0   818.0
# 41  1295.0   565.0
# 42  1050.0   710.0
# 43   901.0   900.0
# 44   567.0   845.0
# 45  1207.0   989.0
# 46   987.0   943.0
# 47   772.0   797.0
# 48   538.0   959.0
# 49   987.0   763.0
# 50   446.0   642.0
# 51   541.0   963.0
# 52   615.0   833.0
# 53  1361.0   775.0
# 54   634.0   821.0
# 55   360.0   809.0
# 56   747.0   900.0
# 57   603.0   629.0
# 58  1768.0   741.0
# 59   169.0   912.0
# /tmp/ipykernel_577360/1168752634.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['percent_organic'].fillna(per_org_mean, inplace=True)
# /tmp/ipykernel_577360/1168752634.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['Fluorescence'].fillna(f_mean, inplace=True)
# /tmp/ipykernel_577360/1168752634.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['g_wet_microfauna'].fillna(microfauna_mean, inplace=True)
# /tmp/ipykernel_577360/1168752634.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['Tardigrades/g_dry'].fillna(tard_mean, inplace=True)
# /tmp/ipykernel_577360/1168752634.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['Rotifers/g_dry'].fillna(rot_mean, inplace=True)
# /tmp/ipykernel_577360/1168752634.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['Ciliates/g_dry'].fillna(cil_mean, inplace=True)
# /tmp/ipykernel_577360/1168752634.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['pH_lab'].fillna(ph_mean, inplace=True)
# /tmp/ipykernel_577360/1168752634.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coo['electrical_conductivity'].fillna(elec_mean, inplace=True)

# %% [markdown]
# ### Taylor Glacier Filling in Missing Values using the Mean of Each Column

# %%
tay = nutrient_data.iloc[60:90]
# print(tay['SampleID'])


per_org_mean = tay['percent_organic'].mean()
f_mean = tay['Fluorescence'].mean()
microfauna_mean = tay['g_wet_microfauna'].mean()
tard_mean = tay['Tardigrades/g_dry'].mean()
rot_mean = tay['Rotifers/g_dry'].mean()
cil_mean = tay['Ciliates/g_dry'].mean()
ph_mean = tay['pH_lab'].mean()
elec_mean = tay['electrical_conductivity'].mean()

tay['percent_organic'].fillna(per_org_mean, inplace=True)
tay['Fluorescence'].fillna(f_mean, inplace=True)
tay['g_wet_microfauna'].fillna(microfauna_mean, inplace=True)
tay['Tardigrades/g_dry'].fillna(tard_mean, inplace=True)
tay['Rotifers/g_dry'].fillna(rot_mean, inplace=True)
tay['Ciliates/g_dry'].fillna(cil_mean, inplace=True)
tay['pH_lab'].fillna(ph_mean, inplace=True)
tay['electrical_conductivity'].fillna(elec_mean, inplace=True)
print(tay)
# Out:
#    SampleID  Fluorescence  percent_organic  g_wet_microfauna  \
# 60   TAR001         2.990             0.32            20.469
# 61   TAR002         2.200             0.35            15.811
# 62   TAR003         2.100             0.31            19.641
# 63   TAR004         4.670             0.34            20.000
# 64   TAR005         5.140             0.46            18.876
# 65   TAR006         1.610             0.27            19.196
# 66   TAR007         2.320             0.36            17.434
# 67   TAR008         1.010             0.33            20.080
# 68   TAR009         1.600             0.32            20.018
# 69   TAR010         1.630             0.37            19.032
# 70   TAR011         1.270             0.35            20.213
# 71   TAR012         1.700             1.48            20.626
# 72   TAR013         2.300             0.28            19.415
# 73   TAR014         1.140             0.26            19.335
# 74   TAR015         1.000             0.29            16.310
# 75   TAR016         2.250             0.30            19.876
# 76   TAR017         0.748             0.29            15.445
# 77   TAR018         1.030             0.27            10.503
# 78   TAR019         1.490             0.32            20.521
# 79   TAR020         2.260             0.31            15.067
# 80   TAR021         1.760             0.35            18.869
# 81   TAR022         2.680             0.32            19.954
# 82   TAR023         2.550             0.28            18.888
# 83   TAR024         3.010             0.36            20.171
# 84   TAR025         4.730             0.28            19.899
# 85   TAR026         2.360             0.29            19.260
# 86   TAR027         2.120             0.27            17.970
# 87   TAR028         3.720             0.34            19.287
# 88   TAR029         1.240             0.36            17.540
# 89   TAR030         1.050             0.30            10.369
#
#     Tardigrades/g_dry  Rotifers/g_dry  Ciliates/g_dry  Diameter_1_cm  \
# 60               0.00            0.02            0.00           19.0
# 61               1.20            0.96            0.08           25.0
# 62               0.05            0.03            0.08           22.0
# 63               0.15            0.03            0.00           26.0
# 64               0.00            1.99            0.07           26.0
# 65               0.00            0.24            0.01           24.0
# 66               0.00            0.39            0.00           21.0
# 67               0.00            0.38            0.00           24.0
# 68               0.00            0.37            6.23           18.0
# 69               0.06            1.44            0.00           24.0
# 70               0.02            0.03            0.00           21.0
# 71               0.00            0.00            0.00           21.0
# 72               4.14            0.76            0.06           23.0
# 73               0.01            0.04            0.10           22.0
# 74               2.92            0.46            0.00           20.0
# 75               0.02            0.00            0.00           20.0
# 76               0.00            0.25            0.00           18.0
# 77               0.02            0.13            0.00           20.0
# 78               0.00            0.00            0.00           19.0
# 79               0.03            0.07            0.00           18.0
# 80               1.19            0.13            0.07           23.0
# 81               0.00            0.44            0.94           20.0
# 82               0.00            0.05            0.00           17.0
# 83               0.00            0.03            0.00           18.0
# 84               0.00            0.06            0.00           19.0
# 85               6.29            1.18            0.13           25.0
# 86               0.15            0.01            0.07           25.0
# 87               0.00            0.04            0.00           22.0
# 88               0.08            0.01            0.02           19.0
# 89               4.84            0.32            0.00           21.0
#
#     Diameter_2_cm  Depth_cm    pH_lab  electrical_conductivity   TC_ppm  \
# 60             19        27  7.210000               118.000000   1110.0
# 61             24        30  7.010000                26.200000   1304.0
# 62             23        38  7.240000                16.040000   1291.0
# 63             26        37  7.160000                29.300000   1531.0
# 64             27        35  7.050000                72.700000   1354.0
# 65             23        35  7.170000                58.700000   1261.0
# 66             21        37  7.350000                30.000000   1232.0
# 67             23        38  7.800000                29.000000  29930.0
# 68             18        39  7.270000                32.000000   1200.0
# 69             25        43  7.480000                26.500000   1280.0
# 70             20        41  7.840000                26.000000   1255.0
# 71             20        38  6.440000                70.300000   1341.0
# 72             23        37  6.920000                65.900000   1327.0
# 73             20        34  7.267778                63.470769   1181.0
# 74             20        33  7.270000                69.200000   1233.0
# 75             21        34  6.480000                29.600000   1301.0
# 76             18        35  8.050000                33.000000   1179.0
# 77             20        39  7.267778                63.470769  25150.0
# 78             19        42  7.980000                47.200000   1236.0
# 79             18        42  7.650000                35.000000   1463.0
# 80             22        36  7.790000                30.500000   1276.0
# 81             20        39  7.430000                93.000000   1220.0
# 82             18        42  7.240000                35.200000   1308.0
# 83             18        41  7.490000                63.470769   1266.0
# 84             29        34  7.580000                23.800000   1846.0
# 85             25        36  6.440000               271.400000   1459.0
# 86             25        34  7.267778                63.470769   1546.0
# 87             22        36  6.510000               325.000000  29300.0
# 88             19        38  7.300000                23.000000   1373.0
# 89             22        37  7.080000                33.700000   1033.0
#
#     TN_ppm  TP_ppm
# 60   142.0   271.0
# 61    61.0   492.0
# 62    60.0   899.0
# 63   175.0   297.0
# 64    27.0   311.0
# 65   169.0   292.0
# 66   127.0   285.0
# 67  3172.0   182.0
# 68    74.0   264.0
# 69   133.0   378.0
# 70    72.0   170.0
# 71   111.0   322.0
# 72   177.0   298.0
# 73   147.0   135.0
# 74   147.0   258.0
# 75     2.0   320.0
# 76   103.0   673.0
# 77  2556.0   206.0
# 78     5.0   275.0
# 79   119.0   198.0
# 80   116.0   182.0
# 81    56.0   131.0
# 82   128.0   157.0
# 83   124.0   214.0
# 84    74.0   290.0
# 85   103.0   263.0
# 86   136.0   257.0
# 87  3054.0   368.0
# 88   128.0   146.0
# 89    49.0   174.0
# /tmp/ipykernel_577360/976859147.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['percent_organic'].fillna(per_org_mean, inplace=True)
# /tmp/ipykernel_577360/976859147.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['Fluorescence'].fillna(f_mean, inplace=True)
# /tmp/ipykernel_577360/976859147.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['g_wet_microfauna'].fillna(microfauna_mean, inplace=True)
# /tmp/ipykernel_577360/976859147.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['Tardigrades/g_dry'].fillna(tard_mean, inplace=True)
# /tmp/ipykernel_577360/976859147.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['Rotifers/g_dry'].fillna(rot_mean, inplace=True)
# /tmp/ipykernel_577360/976859147.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['Ciliates/g_dry'].fillna(cil_mean, inplace=True)
# /tmp/ipykernel_577360/976859147.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['pH_lab'].fillna(ph_mean, inplace=True)
# /tmp/ipykernel_577360/976859147.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tay['electrical_conductivity'].fillna(elec_mean, inplace=True)

# %% [markdown]
# ### Putting the entire dataframe back together

# %%
cleaned = pd.concat([caa, coo, tay], ignore_index=True)
print(cleaned)
# Out:
#    SampleID  Fluorescence  percent_organic  g_wet_microfauna  \
# 0    CAA001     11.900000         0.630000            19.535
# 1    CAA002      2.200000         0.930000            19.763
# 2    CAA003      7.290000         1.052381            20.004
# 3    CAA004      5.955926         1.052381             0.000
# 4    CAA005      5.540000         0.620000            14.263
# ..      ...           ...              ...               ...
# 85   TAR026      2.360000         0.290000            19.260
# 86   TAR027      2.120000         0.270000            17.970
# 87   TAR028      3.720000         0.340000            19.287
# 88   TAR029      1.240000         0.360000            17.540
# 89   TAR030      1.050000         0.300000            10.369
#
#     Tardigrades/g_dry  Rotifers/g_dry  Ciliates/g_dry  Diameter_1_cm  \
# 0            0.220000        0.250000        0.000000           28.0
# 1            0.370000        0.090000        0.000000           27.0
# 2            0.480000        0.730000        0.250000           25.0
# 3            0.744483        0.297241        0.026552           23.0
# 4            0.190000        0.060000        0.000000           17.5
# ..                ...             ...             ...            ...
# 85           6.290000        1.180000        0.130000           25.0
# 86           0.150000        0.010000        0.070000           25.0
# 87           0.000000        0.040000        0.000000           22.0
# 88           0.080000        0.010000        0.020000           19.0
# 89           4.840000        0.320000        0.000000           21.0
#
#     Diameter_2_cm  Depth_cm    pH_lab  electrical_conductivity   TC_ppm  \
# 0              28        22  6.690000                85.900000   2407.0
# 1              27        25  7.095333                93.686667   2602.0
# 2              27        19  7.095333                93.686667   2252.0
# 3              25        23  7.095333                93.686667   3227.0
# 4              19        23  7.870000                64.500000   2100.0
# ..            ...       ...       ...                      ...      ...
# 85             25        36  6.440000               271.400000   1459.0
# 86             25        34  7.267778                63.470769   1546.0
# 87             22        36  6.510000               325.000000  29300.0
# 88             19        38  7.300000                23.000000   1373.0
# 89             22        37  7.080000                33.700000   1033.0
#
#     TN_ppm  TP_ppm
# 0    305.0    19.0
# 1    412.0   270.0
# 2    361.0   114.0
# 3    499.0   261.0
# 4    333.0   163.0
# ..     ...     ...
# 85   103.0   263.0
# 86   136.0   257.0
# 87  3054.0   368.0
# 88   128.0   146.0
# 89    49.0   174.0
#
# [90 rows x 15 columns]
